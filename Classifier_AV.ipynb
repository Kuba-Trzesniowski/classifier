# %% [markdown]
# # Classifier for the probability of a customer's timely loan repayment.

# %% [markdown]
# ## Choosen ML algorithm - Random forest

# %%
import pandas as pd
import numpy as np
import pickle
import statsmodels.api as sm
from sklearn import metrics

import matplotlib.pyplot as plt
plt.style.use('seaborn-ticks')
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. Preparing dataset

# %%
# Import data and replace missing values by mean

df = pd.read_csv ('data_DS_HW_train.csv', sep=None, decimal=',', index_col=0)

df.fillna(df.mean(), inplace=True)

# %%
# Divide columns due to type of data

target = "TARGET"
numFeatures=df.select_dtypes(include='number').columns.tolist()
catFeatures=df.select_dtypes(exclude='number').columns.tolist()

# %%
# Encoding
from sklearn import preprocessing

# Dictionary including maps
mapy = {}
for feature in catFeatures:
    # Encoder initiation
    le = preprocessing.LabelEncoder()
    # Fitting the column
    df[feature] = le.fit_transform(df[feature])
    # Save the map
    mapy[feature] = le

# %%
#Delete "TARGET" column from features set
features = df.columns.tolist()
features.remove(target)

# %% [markdown]
# ### 2. Preparing wrapper to cross validation and first launch

# %%
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score


def CVTestRFClass(nFolds = 5, randomState=2020, debug=False, features=features, *args, **kwargs):
    kf = KFold(n_splits=nFolds, shuffle=True, random_state=randomState)

    # lists to capture results
    testResults = []
    trainResults = []
    predictions = []
    indices = []

    # Loop to validate model over consecutive folds
    for train, test in kf.split(df.index.values):
        # Estimator preparing
        clf = RandomForestClassifier(*args, **kwargs, random_state=randomState, n_jobs=-1)
        if debug:
            print(clf)
        # Train the model
        clf.fit(df.iloc[train][features], df.iloc[train][target])

        # Prepare forecasts for train and test sets
        # UWAGA Sklearn return two columns of probability for both classes
        predsTrain = clf.predict_proba(df.iloc[train][features])[:,1]
        preds = clf.predict_proba(df.iloc[test][features])[:,1]
        
        # Save predictions about fold
        predictions.append(preds.tolist().copy())
        
        # With indexes in original data frame
        indices.append(df.iloc[test].index.tolist().copy())
        
        # Calculate fitting score due to metric ROC-AUC
        trainScore = roc_auc_score((df[target].iloc[train]==1).astype(int), predsTrain)
        testScore = roc_auc_score((df[target].iloc[test]==1).astype(int), preds)
        
        # Save results in list
        trainResults.append(trainScore)
        testResults.append(testScore)
        
        # Informations about every fold with train results able to print during program works
        if debug:
            print("Train AUC:", trainScore,
                  "Valid AUC:", testScore)
        
    return trainResults, testResults, predictions, indices

# %%
#Launch wrapper on prepared dataset

trainResults, testResults, predictions, indices = CVTestRFClass(debug=True)
print(np.mean(testResults))
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=2020)
# Train AUC: 1.0 Valid AUC: 0.9075969827586206
# RandomForestClassifier(n_jobs=-1, random_state=2020)
# Train AUC: 1.0 Valid AUC: 0.9105294723398379
# RandomForestClassifier(n_jobs=-1, random_state=2020)
# Train AUC: 1.0 Valid AUC: 0.9162146591272805
# RandomForestClassifier(n_jobs=-1, random_state=2020)
# Train AUC: 1.0 Valid AUC: 0.916139745175171
# RandomForestClassifier(n_jobs=-1, random_state=2020)
# Train AUC: 1.0 Valid AUC: 0.9193997668997668
# 0.9139761252601353

# %% [markdown]
# ### 3. Boosting results by find best hyperparameters

# %%
# Loop over n_estimators to boost results
for k in [10, 25, 50, 100, 200, 500, 1000]:
    trainResults, testResults, predictions, indices = CVTestRFClass(n_estimators=k)
    print(k, np.mean(trainResults), np.mean(testResults), np.mean(trainResults) - np.mean(testResults))
# Out:
# 10 0.9998375879566304 0.8830157161526193 0.11682187180401105
# 25 0.9999995103176265 0.90402630562448 0.09597320469314641
# 50 1.0 0.9105728745192276 0.08942712548077236
# 100 1.0 0.9139761252601353 0.08602387473986473
# 200 1.0 0.9135435604754519 0.08645643952454807
# 500 1.0 0.914477871251497 0.08552212874850296
# 1000 1.0 0.9149336840574935 0.08506631594250647

# %%
# Loop over max_depth
for k in range(2,22,2):
    trainResults, testResults, predictions, indices = CVTestRFClass(n_estimators=100, max_depth=k)
    print(k, np.mean(trainResults), np.mean(testResults), np.mean(trainResults) - np.mean(testResults))
# Out:
# 2 0.727595349822181 0.7174124142116243 0.01018293561055672
# 4 0.7824029218529794 0.752734122356996 0.029668799495983444
# 6 0.8511660024280945 0.7868046297485811 0.06436137267951336
# 8 0.921340876118505 0.8257407527593965 0.0956001233591085
# 10 0.9693958696642866 0.8583411433579021 0.11105472630638447
# 12 0.9915564408479028 0.8828070200739493 0.10874942077395355
# 14 0.998535019604948 0.8965574043080528 0.1019776152968952
# 16 0.9998110877222501 0.9065761433041905 0.09323494441805968
# 18 0.9999855532476252 0.9101241799523473 0.08986137329527788
# 20 0.9999997508363994 0.912259075665844 0.0877406751705554

# %%
# Loop over max_features
for k in range(2, 50, 2):
    trainResults, testResults, predictions, indices = CVTestRFClass(n_estimators=100, max_depth=10,
                                                                    max_features=k)
    print(k, np.mean(trainResults), np.mean(testResults), np.mean(trainResults) - np.mean(testResults))
# Out:
# 2 0.911709705409223 0.8157750044723814 0.09593470093684164
# 4 0.9362079612687225 0.8343749671805686 0.10183299408815394
# 6 0.950714843016307 0.8426187079404677 0.10809613507583937
# 8 0.9574686093281111 0.8499840060166296 0.10748460331148146
# 10 0.9631773207036558 0.8534713621190921 0.10970595858456367
# 12 0.9666905528488717 0.8573767371001371 0.10931381574873467
# 14 0.9679060863919918 0.8595237452506728 0.10838234114131906
# 16 0.9701192091326833 0.8597843866683093 0.1103348224643741
# 18 0.9713698297917333 0.8597744586406495 0.11159537115108376
# 20 0.9730866084045868 0.8623740982113208 0.110712510193266
# 22 0.9739634060106204 0.8638108636376873 0.11015254237293304
# 24 0.9747055517431115 0.8630122017594154 0.11169334998369607
# 26 0.9757755921754804 0.8663416979006506 0.10943389427482975
# 28 0.975618042436223 0.8647056436676834 0.11091239876853953
# 30 0.977157896503486 0.867120906791164 0.1100369897123219
# 32 0.9768801056055691 0.8644727633392076 0.11240734226636151
# 34 0.9774533450742202 0.8642838794978861 0.11316946557633412
# 36 0.9774643187788954 0.8650680834187296 0.11239623536016574
# 38 0.9777710898288312 0.8677978886240618 0.10997320120476939
# 40 0.9779077170620198 0.8669488067641906 0.11095891029782923
# 42 0.978391470002433 0.8673348154785488 0.11105665452388414
# 44 0.9785372797802644 0.8666892522646747 0.11184802751558964
# 46 0.9784430484673532 0.8656265100536447 0.11281653841370853
# 48 0.978966883298661 0.8677579476343823 0.1112089356642787

# %%
# Loop over min_samples_split
for k in [2, 4, 6, 8, 10, 15, 20, 30]:
    trainResults, testResults, predictions, indices = CVTestRFClass(n_estimators=100, max_depth=10,
                                                                    max_features=12,
                                                                    min_samples_split=k)
    print(k, np.mean(trainResults), np.mean(testResults), np.mean(trainResults) - np.mean(testResults))
# Out:
# 2 0.9666905528488717 0.8573767371001371 0.10931381574873467
# 4 0.9640363138502472 0.8558289863562045 0.10820732749404272
# 6 0.9605926133995337 0.8521457532883744 0.10844686011115934
# 8 0.9570100693473973 0.8481120248423911 0.10889804450500618
# 10 0.9534493942442019 0.8460294804437494 0.10741991380045257
# 15 0.9444088530537578 0.8421659710750008 0.10224288197875697
# 20 0.937313604170494 0.8371264307833648 0.10018717338712924
# 30 0.9248841729251598 0.8296298494192598 0.09525432350590002

# %%
# Loop over min_samples_leaf
for k in range(1, 2, 4):
    trainResults, testResults, predictions, indices = CVTestRFClass(n_estimators=100, max_depth=10,
                                                                    max_features=4,
                                                                    min_samples_split=2, min_samples_leaf=k)
    print(k, np.mean(trainResults), np.mean(testResults))
# Out:
# 1 0.9362079612687225 0.8343749671805686

# %%
# It seems best results is acquire for belowed specification:

# Model 1
trainResults, testResults, predictions, indices = CVTestRFClass(n_estimators=100, max_depth=10,
                                                                    max_features=4,
                                                                    min_samples_split=2, min_samples_leaf=1)
print(k, np.mean(trainResults), np.mean(testResults))

modelRF = {
    "name":"RF",
    "description":"Model RF, ze zmiennymi kategorycznymi z LE",
    "specification":'n_estimators=500, max_depth=20, max_features=4, min_samples_split=4, min_samples_leaf=1',
    "trainResults":trainResults.copy(),
    "testResults":testResults.copy(),
    "predictions":predictions.copy(),
    "indices":indices.copy(),
}
# Out:
# 1 0.9362079612687225 0.8343749671805686

# %% [markdown]
# ### 4.  Finding optimal hyperparameters value - grid search

# %%
# List to save results
results = []

import random
# Loop for consecutive searchings

for k in range(50):
    # Przygotujmy słownik parametrów
    # Previous results are references
    params = {
        "max_depth" : random.randint(6, 11),
        "max_features" : random.randint(8, 12),
        "min_samples_split" : random.randint(2, 6),
    }
    # Value of min_samples_leaf must be smaller than min_samples_split
    params["min_samples_leaf"] = random.randint(1, params["min_samples_split"])
    
    # Model estimation for drawn hyperparameters
    trainResults, testResults, predictions, indices = CVTestRFClass(n_estimators=100,
                                                                    max_depth=params["max_depth"],
                                                                    max_features=params["max_features"],
                                                                    min_samples_split=params["min_samples_split"],
                                                                    min_samples_leaf=params["min_samples_leaf"])
    
    # Save results
    results.append((params.copy(), np.mean(trainResults), np.mean(testResults)))
    
    # Print result of current itaretion
    print(params, np.mean(trainResults), np.mean(testResults))
    
    # Every 10 iterations print top 5 results
    if k>1 and k%10==0:    
        print("\n Top 5:")
        for param, train1, test1 in sorted(results, key=lambda x: x[2], reverse=True)[0:5]:
            print(param, train1, test1)
        print()
# Out:
# {'max_depth': 6, 'max_features': 12, 'min_samples_split': 4, 'min_samples_leaf': 3} 0.8443981166339265 0.7843635333930384
# {'max_depth': 9, 'max_features': 9, 'min_samples_split': 6, 'min_samples_leaf': 1} 0.9332443137155636 0.833422465305536
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 5, 'min_samples_leaf': 1} 0.973437746586046 0.8634170540595123
# {'max_depth': 7, 'max_features': 11, 'min_samples_split': 6, 'min_samples_leaf': 4} 0.8733854429719905 0.798317086394292
# {'max_depth': 8, 'max_features': 9, 'min_samples_split': 5, 'min_samples_leaf': 3} 0.9013046615261826 0.8142751221727487
# {'max_depth': 8, 'max_features': 12, 'min_samples_split': 6, 'min_samples_leaf': 5} 0.9028805814727464 0.816729689615198
# {'max_depth': 8, 'max_features': 10, 'min_samples_split': 5, 'min_samples_leaf': 5} 0.8962236576548397 0.8116393680723037
# {'max_depth': 6, 'max_features': 9, 'min_samples_split': 3, 'min_samples_leaf': 1} 0.8419210948996583 0.782742919888338
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 6, 'min_samples_leaf': 1} 0.9709680086056304 0.8601363515818811
# {'max_depth': 6, 'max_features': 8, 'min_samples_split': 5, 'min_samples_leaf': 2} 0.8374630525208998 0.7812212083688357
# {'max_depth': 7, 'max_features': 11, 'min_samples_split': 4, 'min_samples_leaf': 1} 0.8802861427606338 0.8026646703134416
#
#  Top 5:
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 5, 'min_samples_leaf': 1} 0.973437746586046 0.8634170540595123
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 6, 'min_samples_leaf': 1} 0.9709680086056304 0.8601363515818811
# {'max_depth': 9, 'max_features': 9, 'min_samples_split': 6, 'min_samples_leaf': 1} 0.9332443137155636 0.833422465305536
# {'max_depth': 8, 'max_features': 12, 'min_samples_split': 6, 'min_samples_leaf': 5} 0.9028805814727464 0.816729689615198
# {'max_depth': 8, 'max_features': 9, 'min_samples_split': 5, 'min_samples_leaf': 3} 0.9013046615261826 0.8142751221727487
#
# {'max_depth': 10, 'max_features': 8, 'min_samples_split': 2, 'min_samples_leaf': 2} 0.9504734395731799 0.8438760298707395
# {'max_depth': 11, 'max_features': 12, 'min_samples_split': 4, 'min_samples_leaf': 2} 0.9765160517680247 0.8644495486269212
# {'max_depth': 7, 'max_features': 12, 'min_samples_split': 6, 'min_samples_leaf': 4} 0.8757368848131584 0.8020822932975309
# {'max_depth': 6, 'max_features': 12, 'min_samples_split': 5, 'min_samples_leaf': 4} 0.8428775481118951 0.7836549365765734
# {'max_depth': 10, 'max_features': 12, 'min_samples_split': 4, 'min_samples_leaf': 3} 0.9563215674849441 0.8489252990296077
# {'max_depth': 8, 'max_features': 12, 'min_samples_split': 2, 'min_samples_leaf': 2} 0.9117346575245401 0.8186569304364802
# {'max_depth': 11, 'max_features': 10, 'min_samples_split': 6, 'min_samples_leaf': 6} 0.9531606083231878 0.848340333010734
# {'max_depth': 9, 'max_features': 9, 'min_samples_split': 2, 'min_samples_leaf': 2} 0.933726860575358 0.8332683975281971
# {'max_depth': 11, 'max_features': 11, 'min_samples_split': 5, 'min_samples_leaf': 2} 0.9750275239013064 0.8628607115087444
# {'max_depth': 11, 'max_features': 11, 'min_samples_split': 3, 'min_samples_leaf': 3} 0.9702034819074958 0.8599651599274285
#
#  Top 5:
# {'max_depth': 11, 'max_features': 12, 'min_samples_split': 4, 'min_samples_leaf': 2} 0.9765160517680247 0.8644495486269212
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 5, 'min_samples_leaf': 1} 0.973437746586046 0.8634170540595123
# {'max_depth': 11, 'max_features': 11, 'min_samples_split': 5, 'min_samples_leaf': 2} 0.9750275239013064 0.8628607115087444
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 6, 'min_samples_leaf': 1} 0.9709680086056304 0.8601363515818811
# {'max_depth': 11, 'max_features': 11, 'min_samples_split': 3, 'min_samples_leaf': 3} 0.9702034819074958 0.8599651599274285
#
# {'max_depth': 7, 'max_features': 11, 'min_samples_split': 5, 'min_samples_leaf': 2} 0.8791061625998005 0.8021399501803265
# {'max_depth': 10, 'max_features': 10, 'min_samples_split': 2, 'min_samples_leaf': 2} 0.95835866022282 0.849497439948197
# {'max_depth': 7, 'max_features': 9, 'min_samples_split': 5, 'min_samples_leaf': 4} 0.8682815078679272 0.796229124588578
# {'max_depth': 8, 'max_features': 8, 'min_samples_split': 5, 'min_samples_leaf': 4} 0.892353594304585 0.8098922169551456
# {'max_depth': 11, 'max_features': 11, 'min_samples_split': 2, 'min_samples_leaf': 2} 0.9759725029528463 0.8649604758054338
# {'max_depth': 8, 'max_features': 8, 'min_samples_split': 5, 'min_samples_leaf': 1} 0.9020188957088839 0.8149173945554429
# {'max_depth': 8, 'max_features': 8, 'min_samples_split': 2, 'min_samples_leaf': 1} 0.9052445139867089 0.816386454135916
# {'max_depth': 8, 'max_features': 12, 'min_samples_split': 5, 'min_samples_leaf': 3} 0.9084586345194458 0.81820928477027
# {'max_depth': 10, 'max_features': 9, 'min_samples_split': 2, 'min_samples_leaf': 1} 0.9620449393224881 0.8546463941954616
# {'max_depth': 10, 'max_features': 11, 'min_samples_split': 4, 'min_samples_leaf': 1} 0.9633417737572929 0.8551617483719335
#
#  Top 5:
# {'max_depth': 11, 'max_features': 11, 'min_samples_split': 2, 'min_samples_leaf': 2} 0.9759725029528463 0.8649604758054338
# {'max_depth': 11, 'max_features': 12, 'min_samples_split': 4, 'min_samples_leaf': 2} 0.9765160517680247 0.8644495486269212
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 5, 'min_samples_leaf': 1} 0.973437746586046 0.8634170540595123
# {'max_depth': 11, 'max_features': 11, 'min_samples_split': 5, 'min_samples_leaf': 2} 0.9750275239013064 0.8628607115087444
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 6, 'min_samples_leaf': 1} 0.9709680086056304 0.8601363515818811
#
# {'max_depth': 8, 'max_features': 8, 'min_samples_split': 2, 'min_samples_leaf': 1} 0.9052445139867089 0.816386454135916
# {'max_depth': 11, 'max_features': 8, 'min_samples_split': 3, 'min_samples_leaf': 1} 0.9743129172963279 0.8628205550778805
# {'max_depth': 8, 'max_features': 9, 'min_samples_split': 4, 'min_samples_leaf': 3} 0.9013046615261826 0.8142751221727487
# {'max_depth': 8, 'max_features': 8, 'min_samples_split': 5, 'min_samples_leaf': 3} 0.8974729769073377 0.8126630124687793
# {'max_depth': 7, 'max_features': 12, 'min_samples_split': 2, 'min_samples_leaf': 2} 0.8795688200225079 0.8024009579055431
# {'max_depth': 10, 'max_features': 10, 'min_samples_split': 3, 'min_samples_leaf': 1} 0.9626149774175792 0.8536798613378421
# {'max_depth': 9, 'max_features': 10, 'min_samples_split': 3, 'min_samples_leaf': 3} 0.9310680757622489 0.8320178275146933
# {'max_depth': 11, 'max_features': 12, 'min_samples_split': 6, 'min_samples_leaf': 4} 0.9668194667631786 0.8572805900569082
# {'max_depth': 9, 'max_features': 11, 'min_samples_split': 6, 'min_samples_leaf': 3} 0.9340158185002757 0.8349523878890672
# {'max_depth': 8, 'max_features': 8, 'min_samples_split': 4, 'min_samples_leaf': 2} 0.9007086823736097 0.8117000989567472
#
#  Top 5:
# {'max_depth': 11, 'max_features': 11, 'min_samples_split': 2, 'min_samples_leaf': 2} 0.9759725029528463 0.8649604758054338
# {'max_depth': 11, 'max_features': 12, 'min_samples_split': 4, 'min_samples_leaf': 2} 0.9765160517680247 0.8644495486269212
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 5, 'min_samples_leaf': 1} 0.973437746586046 0.8634170540595123
# {'max_depth': 11, 'max_features': 11, 'min_samples_split': 5, 'min_samples_leaf': 2} 0.9750275239013064 0.8628607115087444
# {'max_depth': 11, 'max_features': 8, 'min_samples_split': 3, 'min_samples_leaf': 1} 0.9743129172963279 0.8628205550778805
#
# {'max_depth': 11, 'max_features': 9, 'min_samples_split': 5, 'min_samples_leaf': 4} 0.9610555238612994 0.8537347845986261
# {'max_depth': 10, 'max_features': 9, 'min_samples_split': 4, 'min_samples_leaf': 4} 0.9443339331395432 0.8410151395338188
# {'max_depth': 7, 'max_features': 8, 'min_samples_split': 5, 'min_samples_leaf': 3} 0.8668051424712345 0.7963036950577715
# {'max_depth': 10, 'max_features': 9, 'min_samples_split': 2, 'min_samples_leaf': 1} 0.9620449393224881 0.8546463941954616
# {'max_depth': 7, 'max_features': 10, 'min_samples_split': 4, 'min_samples_leaf': 4} 0.8711588538999324 0.7988398351067791
# {'max_depth': 6, 'max_features': 12, 'min_samples_split': 4, 'min_samples_leaf': 4} 0.8428775481118951 0.7836549365765734
# {'max_depth': 8, 'max_features': 12, 'min_samples_split': 4, 'min_samples_leaf': 4} 0.9054867978357277 0.817878708017745
# {'max_depth': 7, 'max_features': 12, 'min_samples_split': 3, 'min_samples_leaf': 1} 0.8821006130765147 0.8035981326656094
# {'max_depth': 9, 'max_features': 12, 'min_samples_split': 4, 'min_samples_leaf': 4} 0.9303005899316827 0.8306090496252121

# %%
# Grid search method brings best result with these values of hyperparams:

# Model 2
trainResults, testResults, predictions, indices = CVTestRFClass(n_estimators=100, max_depth=11,
                                                                    max_features=8,
                                                                    min_samples_split=4, min_samples_leaf=1)
print(k, np.mean(trainResults), np.mean(testResults))

modelRF = {
    "name":"RF",
    "description":"Model RF, ze zmiennymi kategorycznymi z LE",
    "specification":'n_estimators=500, max_depth=20, max_features=4, min_samples_split=4, min_samples_leaf=1',
    "trainResults":trainResults.copy(),
    "testResults":testResults.copy(),
    "predictions":predictions.copy(),
    "indices":indices.copy(),
}
# Out:
# 49 0.9720148677063827 0.8600271975943612

# %% [markdown]
# ###### Due to both of these results to the main part of the analysis will be used <number of model> model. It is possible to look variables were most important during modeling.

# %% [markdown]
# ### 5. Feature importance

# %%
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score


# Preparing wrapper
def CVTestRFClass(nFolds = 5, randomState=2020, debug=False, features=features, saveModels = False, *args, **kwargs):
    
    # Preparing cross-validation
    kf = KFold(n_splits=nFolds, shuffle=True, random_state=randomState)

    # To save the memory information about the fols are only numbers of rows
    testResults = []
    
    # Adding information about train set
    trainResults = []
    
    # Store predictions for every single fold
    predictions = []
    
    # With index in original dataset
    indices = []
    
    # Preparing list of models to store
    models = []
    
    # Loop to models validating
    for train, test in kf.split(df.index.values):
        # Preparing estimator
        clf = RandomForestClassifier(*args, **kwargs, random_state=randomState, n_jobs=-1)
        if debug:
            print(clf)
        # Model testing
        clf.fit(df.iloc[train][features], df.iloc[train][target])

        # Preparing forecasts for train and test datasets
        predsTrain = clf.predict_proba(df.iloc[train][features])[:,1]
        preds = clf.predict_proba(df.iloc[test][features])[:,1]
        
        # Store forecasts informations about fold
        predictions.append(preds.tolist().copy())
        
        # With their indexes in original dataframe
        indices.append(df.iloc[test].index.tolist().copy())
        
        # Calculate fitting score by ROC-AUC metric
        trainScore = roc_auc_score((df[target].iloc[train]==1).astype(int), predsTrain)
        testScore = roc_auc_score((df[target].iloc[test]==1).astype(int), preds)
        
        # Save iteration results
        trainResults.append(trainScore)
        testResults.append(testScore)
        
        # Informatio about every fold with train results are possible to print during calculating
        if debug:
            print("Train AUC:", trainScore,
                  "Valid AUC:", testScore)
        
        # Save results in model's list
        if saveModels:
            models.append(clf)
    
    # List of returnig results with new variable - models
    return trainResults, testResults, predictions, indices, models

# %%
trainResults, testResults, predictions, indices, models = CVTestRFClass(n_estimators=100, max_depth=11,
                                                                    max_features=8,
                                                                    min_samples_split=4, min_samples_leaf=1,
                                                                        saveModels=True)

# %%
# Print list of features frequency
imps = list(zip(models[0].feature_importances_, features))
imps.sort(reverse=True)
imps
# Out:
# [(0.01845588034248679,
#   'swo_ind_same_pesel_different_lender_count_unique_p0_30'),
#  (0.0172654470163505, 'swo_ind_loans_amount_p0_210'),
#  (0.016142303228840273, 'swo_ind_same_pesel_applications_count_p0_30'),
#  (0.01575806886447401, 'swo_ind_loans_amount_p0_plus'),
#  (0.01574297584640283,
#   'swo_ind_same_pesel_different_lender_count_unique_p0_7'),
#  (0.015225114419605914, 'swo_ind_loans_number_p0_plus'),
#  (0.014991410496605535, 'sumpaiddebt'),
#  (0.014867623173844163, 'score'),
#  (0.014524489065822842, 'swo_ind_same_pesel_applications_count_p0_7'),
#  (0.014365524865479604, 'swo_ind_loans_amount_p0_360'),
#  (0.013462641994346927,
#   'swo_ind_same_pesel_different_lender_count_unique_p0_90'),
#  (0.013451663174098656, 'chap_coef'),
#  (0.013441536768877044, 'swo_ind_same_pesel_applications_count_p0_90'),
#  (0.013212011091770542, 'swo_ind_loans_amount_p0_90'),
#  (0.012741799751542089, 'swo_ind_loans_number_p0_210'),
#  (0.0126934595217492, 'averagepaiddebt'),
#  (0.01238538092216892, 'swo_ind_same_pesel_applications_count_p0_360'),
#  (0.011671069549187755, 'income_charge'),
#  (0.011411527000281025, 'swo_ind_loans_number_p0_360'),
#  (0.011356734484988034, 'paidobligationscount'),
#  (0.01089221693392522,
#   'swo_ind_same_pesel_different_lender_count_unique_p0_360'),
#  (0.010832550246993911, 'swo_ind_same_pesel_applications_count_p0_210'),
#  (0.010733183519307656,
#   'swo_ind_same_pesel_different_lender_count_unique_p0_210'),
#  (0.010588376945181681, 'days_after_last_positive_accounts'),
#  (0.00990924662575892, 'min_prepaid_days'),
#  (0.009855371673876435, 'sum_positive_accounts'),
#  (0.009828379952410139, 'num_prepaid_loans'),
#  (0.009748439285930987, 'days_after_first_positive_accounts'),
#  (0.009676431645807844, 'swo_ind_active_loans_open_amount'),
#  (0.00963497990135741, 'customerincomecurrent'),
#  (0.009627445013849004, 'diff_customerincome'),
#  (0.00951954938453771, 'swo_ind_active_loans_amount'),
#  (0.009240464660361908, 'loan_date_created'),
#  (0.009056291570726323, 'avg_prepaid_days'),
#  (0.009035793032562363,
#   'swo_ind_same_pesel_different_lender_count_unique_p0_3'),
#  (0.009001673987144042, 'swo_ind_loans_number'),
#  (0.008915094623231324, 'applicationprice'),
#  (0.008571114823477784, 'providerscount'),
#  (0.008267313252764108, 'days_after_knownsince_pbd'),
#  (0.008165398013917906, 'max_prepaid_days'),
#  (0.008066729741954558, 'averagepaymenttimeindays'),
#  (0.008066617522081576,
#   'swo_ind_same_pesel_different_phone_count_unique_p0_90'),
#  (0.008004016730663976, 'swo_ind_same_pesel_applications_count_p0_3'),
#  (0.007945481215907541,
#   'swo_ind_same_main_address_different_pesel_count_p0_360'),
#  (0.007861845543747237, 'swo_ind_loans_amount_p0_30'),
#  (0.007850693313125243, 'applicationamount'),
#  (0.007790865965822524, 'swo_ind_closed_paid_loans_lenders_number'),
#  (0.007787261757354257, 'avg_dpd'),
#  (0.007732436391311235, 'swo_ind_loans_number_p0_90'),
#  (0.007499384327967971, 'num_paid_loans_with_dpd_to_all'),
#  (0.0073453012237031465, 'countrejectedapplications'),
#  (0.006893316180243974,
#   'swo_ind_same_pesel_different_phone_count_unique_p0_30'),
#  (0.006892036517672413,
#   'swo_ind_same_pesel_different_phone_count_unique_p0_360'),
#  (0.006867736591109579, 'correspondence_address_different_pesel_count_p0_360'),
#  (0.00625222427318657, 'max_dpd'),
#  (0.006037914343797347, 'num_positive_accounts'),
#  (0.006035421907503189, 'employmentstatus'),
#  (0.0056903536713457815, 'swo_ind_active_loans_number_p0_plus'),
#  (0.005655853612109218, 'swo_ind_same_pesel_applications_count_p0_1'),
#  (0.005537664830154586,
#   'swo_ind_same_pesel_different_phone_count_unique_p0_210'),
#  (0.005349618209932659,
#   'swo_ind_same_pesel_different_main_address_count_p0_360'),
#  (0.0053275112721150215,
#   'swo_ind_same_main_address_different_pesel_count_p0_210'),
#  (0.005224069634289449,
#   'correspondence_address_different_pesel_count_unique_p0_360'),
#  (0.005209531517216078,
#   'swo_ind_same_main_address_different_pesel_count_unique_p0_360'),
#  (0.005206864337586147,
#   'swo_ind_same_pesel_different_main_address_count_p0_210'),
#  (0.005193945243814174, 'swo_ind_loans_amount_p0_7'),
#  (0.005066060605540785, 'swo_ind_active_loans_number_p0_210'),
#  (0.005046267261248892, 'daysafterregistration'),
#  (0.0049842832280262575, 'num_paid_loans_with_dpd'),
#  (0.004901172588361296, 'identificationtype'),
#  (0.0048849202552562945,
#   'swo_ind_same_pesel_different_main_address_count_p0_90'),
#  (0.004824374462221584, 'correspondence_address_different_pesel_count_p0_210'),
#  (0.0048212595281825095, 'swo_ind_active_loans_number_p0_360'),
#  (0.004754690091115312,
#   'swo_ind_same_pesel_different_main_address_count_unique_p0_360'),
#  (0.00463166096294071, 'swo_ind_active_loans_number_p0_30'),
#  (0.004622270432051918, 'swo_ind_loans_amount_p0_3'),
#  (0.004540679990553899,
#   'swo_ind_same_pesel_different_main_address_count_p0_30'),
#  (0.004470032037188169, 'companiesinhouse'),
#  (0.004464807041551239, 'amount'),
#  (0.0043448757203961895,
#   'swo_ind_same_main_address_different_pesel_count_p0_30'),
#  (0.004342252629810917, 'housesize'),
#  (0.004325780408237018,
#   'swo_ind_same_main_address_different_pesel_count_p0_90'),
#  (0.004258191625022756,
#   'correspondence_address_different_pesel_count_unique_p0_210'),
#  (0.004222201606295784,
#   'swo_ind_same_pesel_different_phone_count_unique_p0_7'),
#  (0.004203958510244784, 'swo_ind_active_loans_number'),
#  (0.004155798901157584, 'swo_ind_loans_number_p0_30'),
#  (0.004130699283704554, 'count'),
#  (0.004124840169021492,
#   'swo_ind_same_pesel_different_main_address_count_unique_p0_90'),
#  (0.004079170030137813,
#   'swo_ind_same_main_address_different_pesel_count_unique_p0_210'),
#  (0.003997993355484846, 'swo_ind_active_loans_number_p0_90'),
#  (0.003989585100613739,
#   'swo_ind_same_pesel_different_main_address_count_unique_p0_210'),
#  (0.003948208736020073, 'pesel_different_correspondence_address_count_p0_210'),
#  (0.0038221082123021393, 'citysize'),
#  (0.003805492818394967,
#   'swo_ind_same_pesel_different_lender_count_unique_p0_1'),
#  (0.00379824927667386, 'pesel_different_correspondence_address_count_p0_90'),
#  (0.0037473157327824243,
#   'swo_ind_same_main_address_different_pesel_count_unique_p0_90'),
#  (0.0037228720512928865, 'amounttotal'),
#  (0.0036456128566047974, 'correspondence_address_different_pesel_count_p0_90'),
#  (0.0036368003771022946,
#   'correspondence_address_different_pesel_count_unique_p0_90'),
#  (0.0035192783348181223,
#   'pesel_different_correspondence_address_count_unique_p0_360'),
#  (0.003383504572548225,
#   'swo_ind_same_pesel_different_main_address_count_unique_p0_30'),
#  (0.003382843020503481, 'householdsize'),
#  (0.0033464361695863987, 'swo_ind_loans_number_p0_7'),
#  (0.003302744711128032, 'num_paid_loans_on_time'),
#  (0.0031391706083587533, 'swo_ind_active_loans_number_p0_7'),
#  (0.0031144674694024215, 'housetype'),
#  (0.0031019341193723755, 'creditstatusmax'),
#  (0.003092606964522408, 'pesel_different_correspondence_address_count_p0_360'),
#  (0.0030580610018174125, 'swo_ind_same_pesel_different_idcard_count_p0_360'),
#  (0.00301733849639701, 'correspondence_address_different_pesel_count_p0_30'),
#  (0.002952899629211733,
#   'pesel_different_correspondence_address_count_unique_p0_210'),
#  (0.002952314093439117, 'customerincomeprevious'),
#  (0.002879315310902476, 'creditorscount'),
#  (0.00282796099915215, 'amounttotalopen'),
#  (0.0027999964291927524, 'onavgdpd'),
#  (0.002760940862897267, 'swo_ind_same_phone_different_pesel_count_p0_360'),
#  (0.00275943738605645, 'swo_ind_same_pesel_different_idcard_count_p0_210'),
#  (0.0026893285474047218,
#   'swo_ind_same_phone_different_pesel_count_unique_p0_360'),
#  (0.002563118876047425,
#   'swo_ind_same_main_address_different_pesel_count_unique_p0_30'),
#  (0.002544224476983858,
#   'swo_ind_same_pesel_different_main_address_count_p0_7'),
#  (0.0025342141810918684,
#   'pesel_different_correspondence_address_count_unique_p0_30'),
#  (0.002521719514529681, 'chap_countrejectedapplications'),
#  (0.002496387638944493, 'legalform'),
#  (0.0024889383068337346,
#   'swo_ind_same_pesel_different_idcard_count_unique_p0_360'),
#  (0.0024811402721530594,
#   'swo_ind_same_main_address_different_pesel_count_p0_7'),
#  (0.0024797149699367885, 'pesel_different_correspondence_address_count_p0_30'),
#  (0.0024448098942984582, 'max_onmaxdpd'),
#  (0.002432139200383405, 'max_ondpd_ext'),
#  (0.002431657552890265, 'informationcount'),
#  (0.0023606196038187567, 'swo_ind_same_pesel_different_idcard_count_p0_90'),
#  (0.0022112145291810054,
#   'pesel_different_correspondence_address_count_unique_p0_90'),
#  (0.0021769857953793737, 'avgbetweenapprovedapplications'),
#  (0.0021362730169983677, 'swo_ind_loans_number_p0_3'),
#  (0.002126968347487299, 'swo_ind_active_loans_number_p0_3'),
#  (0.002119869807089612, 'swo_ind_same_ip_different_pesel_count'),
#  (0.0020857034728748807, 'onsex'),
#  (0.0020699351831212536,
#   'correspondence_address_different_pesel_count_unique_p0_30'),
#  (0.0020648678229417605,
#   'swo_ind_same_main_address_different_pesel_count_p0_3'),
#  (0.0020646304967730923, 'oinformationcount'),
#  (0.0019873566191424222, 'value'),
#  (0.0019680910518810875, 'swo_ind_same_phone_different_pesel_count_p0_210'),
#  (0.0019268723602864032, 'swo_ind_same_pesel_different_idcard_count_p0_30'),
#  (0.00191793319242408,
#   'swo_ind_same_pesel_different_main_address_count_unique_p0_7'),
#  (0.0019163333867912075, 'onmaxdpd_ext_coalt'),
#  (0.0018893839678849732, 'activeloan_coalt'),
#  (0.0018891883857075698,
#   'swo_ind_same_main_address_different_pesel_count_p0_1'),
#  (0.0018820113622149376, 'gender'),
#  (0.0018430686823066337,
#   'swo_ind_same_pesel_different_idcard_count_unique_p0_210'),
#  (0.0017822986522121234, 'avgloanterm'),
#  (0.0017727613499860149, 'swo_ind_overdue_loans_number_p0_30'),
#  (0.0017419303676544054,
#   'swo_ind_same_main_address_different_pesel_count_unique_p0_7'),
#  (0.001737823463825984, 'swo_ind_overdue_loans_number_p0_plus'),
#  (0.001700750248931393, 'swo_ind_overdue_loans_number_p0_210'),
#  (0.001691396811849121, 'max_ondpd'),
#  (0.0016864341782152359, 'onmaxdpd_coalt'),
#  (0.0016779645920348529, 'swo_ind_overdue_loans_number_p0_90'),
#  (0.0016426666588181557, 'max_onmaxdpd_ext'),
#  (0.001641393873272381, 'correspondence_address_different_pesel_count_p0_3'),
#  (0.0016309384926050375, 'debtorscount'),
#  (0.001620096132708893, 'masterriskstatus_no_negative_history'),
#  (0.001570553984512146, 'swo_ind_overdue_loans_number_p0_7'),
#  (0.0015617010388176364, 'countrejectedapplicationsafterlastloanclose'),
#  (0.0015528701913504778, 'ondpd_ext_coalt'),
#  (0.0015401246436884102, 'swo_ind_loans_amount_p0_1'),
#  (0.0015325722381821596, 'pesel_different_correspondence_address_count_p0_7'),
#  (0.001506364961714105, 'ondpd_coalt'),
#  (0.001501718127019858,
#   'swo_ind_same_pesel_different_idcard_count_unique_p0_90'),
#  (0.0014971333519952967, 'policyrule_partialdecision'),
#  (0.0014937000997662037, 'swo_ind_same_phone_different_pesel_count_p0_90'),
#  (0.00144283649606431, 'swo_ind_overdue_loans_number_p0_360'),
#  (0.0014041943292064344, 'swo_ind_overdue_loans_number'),
#  (0.0013477609692594842,
#   'swo_ind_same_pesel_different_phone_count_unique_p0_3'),
#  (0.0013463723455476983,
#   'pesel_different_correspondence_address_count_unique_p0_7'),
#  (0.001312519834523417,
#   'swo_ind_same_pesel_different_main_address_count_p0_3'),
#  (0.0012484024472565053, 'correspondence_address_different_pesel_count_p0_7'),
#  (0.0012435626833879666, 'swo_ind_same_ip_different_pesel_count_unique'),
#  (0.0012384260024287295, 'decision'),
#  (0.0011785809184571498,
#   'swo_ind_same_phone_different_pesel_count_unique_p0_210'),
#  (0.001130303418912716,
#   'swo_ind_same_pesel_different_idcard_count_unique_p0_30'),
#  (0.0011282316887421993, 'swo_ind_overdue_loans_sum_1001_5000_p0_210'),
#  (0.0011223118661533129,
#   'swo_ind_same_pesel_different_main_address_count_unique_p0_3'),
#  (0.0010654916913856087,
#   'correspondence_address_different_pesel_count_unique_p0_7'),
#  (0.00106348988839993,
#   'swo_ind_same_phone_different_pesel_count_unique_p0_90'),
#  (0.0010499926775737335, 'swo_ind_same_pesel_different_idcard_count_p0_7'),
#  (0.0010315837225972624,
#   'correspondence_address_different_pesel_count_unique_p0_3'),
#  (0.0009978038952094574,
#   'swo_ind_same_pesel_different_main_address_count_p0_1'),
#  (0.000964549142685475, 'swo_ind_overdue_loans_sum_1001_5000_p0_90'),
#  (0.0009548107991539788, 'avgbetweenapplications'),
#  (0.0009477308068987382, 'max_onlastloandpd_ext'),
#  (0.0009452177677154687, 'swo_ind_overdue_loans_sum_1001_5000_p0_plus'),
#  (0.0009371822349743978, 'swo_ind_active_loans_number_p0_1'),
#  (0.0009273899087073609,
#   'swo_ind_same_phone_different_pesel_count_unique_p0_30'),
#  (0.000901404595280283,
#   'swo_ind_same_main_address_different_pesel_count_unique_p0_1'),
#  (0.0008908871774187433, 'swo_ind_overdue_loans_number_p0_3'),
#  (0.0008896638175661859,
#   'swo_ind_same_main_address_different_pesel_count_unique_p0_3'),
#  (0.0008838133526068051,
#   'swo_ind_same_pesel_different_main_address_count_unique_p0_1'),
#  (0.0008416240662232101, 'swo_ind_loans_number_p0_1'),
#  (0.0008360376801865107, 'swo_ind_same_pesel_different_idcard_count_p0_3'),
#  (0.0008298913879754761, 'swo_ind_same_phone_different_pesel_count_p0_30'),
#  (0.0008240915098458921, 'swo_ind_overdue_loans_sum_1001_5000_p0_30'),
#  (0.0008197983552190255, 'pesel_different_correspondence_address_count_p0_1'),
#  (0.0007931568261022534, 'avgextensions'),
#  (0.0007807033272952696, 'swo_ind_overdue_loans_sum_501_1000_p0_plus'),
#  (0.0007686021231071414, 'onlastloandpd_ext_coalt'),
#  (0.0007661642718556646, 'swo_ind_overdue_loans_sum_1001_5000_p0_3'),
#  (0.0007510446658588228, 'swo_ind_overdue_loans_sum_501_1000_p0_90'),
#  (0.0007271394148637414, 'swo_ind_overdue_loans_sum_1001_5000_p0_360'),
#  (0.0007223973385518801, 'masterriskstatus_postempowanie'),
#  (0.0007114432373467447, 'swo_ind_overdue_loans_sum_501_1000_p0_7'),
#  (0.0007003190442953077, 'countapplicationsafterlastloanclose'),
#  (0.0006958899941153561,
#   'swo_ind_same_pesel_different_idcard_count_unique_p0_7'),
#  (0.0006788061124824181, 'swo_ind_overdue_loans_sum_501_1000_p0_210'),
#  (0.0006757913058798575, 'swo_ind_overdue_loans_sum_1001_5000_p0_7'),
#  (0.0006725699182855939,
#   'pesel_different_correspondence_address_count_unique_p0_3'),
#  (0.0006649608962083305,
#   'swo_ind_same_pesel_different_phone_count_unique_p0_1'),
#  (0.0006443402785579585, 'pesel_different_correspondence_address_count_p0_3'),
#  (0.0006123468128370604, 'swo_ind_same_pesel_different_idcard_count_p0_1'),
#  (0.0005975398215076945, 'score_partialdecision'),
#  (0.0005969439767696637, 'swo_ind_overdue_loans_sum_501_1000_p0_30'),
#  (0.0005813059886471566, 'swo_ind_overdue_loans_sum_501_1000_p0_360'),
#  (0.000532814563526287,
#   'correspondence_address_different_pesel_count_unique_p0_1'),
#  (0.0005115046201475209,
#   'pesel_different_correspondence_address_count_unique_p0_1'),
#  (0.0005026971669338475,
#   'swo_ind_same_phone_different_pesel_count_unique_p0_7'),
#  (0.0004993102925227774, 'correspondence_address_different_pesel_count_p0_1'),
#  (0.0004908480910544362,
#   'swo_ind_same_pesel_different_idcard_count_unique_p0_3'),
#  (0.000485067958197477,
#   'swo_ind_same_pesel_different_idcard_count_unique_p0_1'),
#  (0.0004831890043186419, 'swo_ind_canceled_loans_number_p2_plus'),
#  (0.0003958306845915627, 'swo_ind_overdue_loans_number_p0_1'),
#  (0.00036400394703309225, 'swo_ind_canceled_loans_number_p2_360'),
#  (0.00029395139506549153, 'repetitionfilter'),
#  (0.00020931077210859084, 'chap_countapplication'),
#  (0.00013167323012577736, 'swo_ind_canceled_loans_number_p2_90'),
#  (8.807285467359656e-05, 'swo_ind_canceled_loans_number_p2_210')]

# %% [markdown]
# ###### Here we can see wchich variaables were most important during the validation process. It could be useful business information for future modeling.

# %% [markdown]
# ### 6. Test sample - probability predictions

# %%
# Import data and replace missing values by mean
df_t = pd.read_csv ('data_DS_HW_test.csv', sep=None, decimal=',', index_col=0)
df_t.fillna(df_t.mean(), inplace=True)

# %%
# Divide columns due to type of data
numFeatures_t=df_t.select_dtypes(include='number').columns.tolist()
catFeatures_t=df_t.select_dtypes(exclude='number').columns.tolist()

# %%
# Encoding
from sklearn import preprocessing

# Dictionary including maps
mapy = {}
for feature in catFeatures_t:
    # Encoder initiation
    le = preprocessing.LabelEncoder()
    # Fitting the column
    df_t[feature] = le.fit_transform(df_t[feature])
    # Save the map
    mapy[feature] = le

# %%
# Create features set
features = df_t.columns.tolist()

# %%
# For the probabilities capture would be use model with best specification on the train set with belowed specification:
clf = RandomForestClassifier(n_estimators=100, max_depth=11, max_features=8, min_samples_split=4, min_samples_leaf=1, 
                             random_state=2022, n_jobs=-1)
clf.fit(df[features], df[target])
# Out:
# RandomForestClassifier(max_depth=11, max_features=8, min_samples_split=4,
#                        n_jobs=-1, random_state=2022)

# %%
# Calculating probabilities
data=pd.DataFrame()
for i in range (5):
    preds = (clf.predict_proba(df_t.iloc[i].array.reshape(1, -1)))
    data = data.append(preds.tolist().copy())
    
data.rename(columns = {0:'probability_of_0', 1:'probability_of_1'}, inplace = True)

# %%
# Create a file with probabilities
result = pd.DataFrame(zip(df_t.index, data['probability_of_1']))
result.rename(columns = {0:'application_id', 1:'probability_of_1'}, inplace = True)
result.set_index('application_id')
# Out:
#                 probability_of_1
# application_id
# 223                     0.091164
# 20671                   0.437221
# 2218                    0.195571
# 19196                   0.123065
# 13088                   0.305594

# %%
# Save the file as 'xlsx' same path
result.to_excel("probabilities.xlsx")
